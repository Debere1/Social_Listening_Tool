# %%
import pandas as pd

# %%
df= pd.read_csv('/content/ExploreAI social media data - FB.csv')

# %%
df.tail(50)
# Out:
#                               Post ID Post creation date  \
# 384  926011594215556_2455113144638719         2022-11-21
# 385  926011594215556_2455113144638719         2022-11-21
# 386  926011594215556_2455113144638719         2022-11-21
# 387  926011594215556_2457575547725812         2022-11-24
# 388  926011594215556_2457575547725812         2022-11-24
# 389  926011594215556_2458575064292527         2022-11-25
# 390  926011594215556_2461283444021689         2022-11-28
# 391  926011594215556_2461872133962820         2022-11-29
# 392  926011594215556_2462789497204417         2022-11-30
# 393  926011594215556_2462789497204417         2022-11-30
# 394  926011594215556_2462789497204417         2022-11-30
# 395  926011594215556_2462789497204417         2022-11-30
# 396  926011594215556_2462789497204417         2022-11-30
# 397  926011594215556_2462789497204417         2022-11-30
# 398  926011594215556_2462789497204417         2022-11-30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 19 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Post ID                                     434 non-null    object
#  1   Post creation date                          434 non-null    object
#  2   Post creation time of day                   434 non-null    object
#  3   Post type                                   434 non-null    object
#  4   Post message                                434 non-null    object
#  5   Post shared link                            434 non-null    object
#  6   Post caption                                308 non-null    object
#  7   Post thumbnail URL                          421 non-null    object
#  8   Post image URL                              421 non-null    object
#  9   Link to post                                434 non-null    object
# ...

# %%
df.shape
# Out:
# (434, 19)

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Post ID                                        0.000000
# Post creation date                             0.000000
# Post creation time of day                      0.000000
# Post type                                      0.000000
# Post message                                   0.000000
# Post shared link                               0.000000
# Post caption                                  29.032258
# Post thumbnail URL                             2.995392
# Post image URL                                 2.995392
# Link to post                                   0.000000
# Post comment text                             35.023041
# Total post reactions                           0.000000
# Post link clicks                              44.470046
# Likes on posts                                 0.000000
# Shares on posts                               36.405530
# Comments on posts                              0.000000
# Comments on shares                             0.000000
# ...

# %%
df.corr()
# Out:
# <ipython-input-15-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                             Total post reactions  \
# Total post reactions                                    1.000000
# Post link clicks                                        0.240089
# Likes on posts                                          0.992788
# Shares on posts                                         0.221838
# Comments on posts                                       0.178158
# Comments on shares                                      0.188613
# Post impressions (page likers [fans] only)              0.279139
# Post reach (page likers [fans] only)                    0.259410
#
#                                             Post link clicks  Likes on posts  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df1 = df[['Post creation date', 'Total post reactions', 'Likes on posts', 'Shares on posts', 'Comments on posts', 'Comments on shares', 'Post impressions (page likers [fans] only)','Post reach (page likers [fans] only)']].groupby(['Post creation date']).sum().reset_index()

# %%
px.line(df1, x='Post creation date', y= 'Total post reactions')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(df1, x='Post creation date', y= 'Post impressions (page likers [fans] only)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(df1, x='Post creation date', y= 'Likes on posts')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(df1, x='Post creation date', y= 'Comments on posts')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(df1, x='Post creation date', y= 'Post reach (page likers [fans] only)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
